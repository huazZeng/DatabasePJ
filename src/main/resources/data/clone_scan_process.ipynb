# %%
import os
import pandas as pd
mysql_conn_str = 'mysql+pymysql://root:0301zhz@localhost/database_pj'

# %%
def read_csv(file_path, encoding='utf-8'):
    with open(file_path, 'r', encoding=encoding) as file:
        return pd.read_csv(file)

# %%
import pymysql
from sqlalchemy import create_engine
host = 'localhost'
user = 'root'
password = '0301zhz'
database = 'database_pj'

# 建立到MySQL数据库的连接
conn = pymysql.connect(
    host=host,
    user=user,
    password=password,
    database=database
)

# %%
cursor = conn.cursor()
# create_table_query = """
# CREATE TABLE IF NOT EXISTS clone_scan (
#     commit_id VARCHAR(255) PRIMARY KEY,
#     developer VARCHAR(255),
#     commit_time DATETIME
# );
# """
# cursor.execute(create_table_query)
# conn.commit()

# %%
commit_records_filepath = r'src\main\resources\data\user.csv'
commit_records=read_csv(commit_records_filepath)
print(commit_records.head())
# Write DataFrame to MySQL table
engine = create_engine(mysql_conn_str)
commit_records[["id","name","type","password","s_id","age","gender"]].to_sql('user', con=engine, if_exists='append', index=False)
# Close cursor and connection
cursor.close()
conn.close()
# Out:
#    id              name        type          password          s_id  age  \
# 0   1  Clemence Picardo     student     rW8~*e\|#xAep  333-503-4825   74
# 1   2    Jaymee Farmloe     student  cW5<6SSi5Qu'6N(~  711-181-8589   59
# 2   3  Agathe MacCallum     student        gM5#hUID9D  074-309-6845   44
# 3   4  Sterling Walburn     student     nN6_l3J|xLuzs  513-734-1875   66
# 4   5      Kat Woolston  instructor       tK9@`=*>H`V  671-203-7490   70
#
#   gender
# 0      F
# 1      F
# 2      F
# 3      M
# 4      F

# %%
commit_records_filepath = r'src\main\resources\data\caterer.csv'
commit_records=read_csv(commit_records_filepath)
print(commit_records.head())
# Write DataFrame to MySQL table
engine = create_engine(mysql_conn_str)
commit_records[["id","name","password","address","main_food_name"]].to_sql('caterer', con=engine, if_exists='append', index=False)
# Close cursor and connection
cursor.close()
# conn.close()
# Out:
#    id         name        password                   address main_food_name
# 0   1      Centizu    jY5>Q6c\8.?S             5 Maywood Way           taco
# 1   2      Yakidoo  jT4&W.FIFbey~Q  008 International Circle          salad
# 2   3         Vipe        zT6&u<'W   21322 Lotheville Center          pasta
# 3   4  Brainlounge  jM3@lnTI#uAdP.            1 Donald Court        burrito
# 4   5       Trunyx        rP4%zJ<P       56957 Bluejay Drive          steak

# %%
commit_records_filepath = r'src\main\resources\data\book.csv'
commit_records=read_csv(commit_records_filepath)
print(commit_records.head())
# Write DataFrame to MySQL table
engine = create_engine(mysql_conn_str)
commit_records[["id","user_id","caterer_id","time"]].to_sql('book', con=engine, if_exists='append', index=False)
# Close cursor and connection
cursor.close()
# Out:
#    id  user_id  caterer_id                 time
# 0   1        1           3  2024-05-01 12:30:00
# 1   2        2           5  2024-05-02 13:00:00
# 2   3        3           7  2024-05-03 11:45:00
# 3   4        4           2  2024-05-04 12:15:00
# 4   5        5           6  2024-05-05 13:30:00

# %%
commit_records_filepath = r'src\main\resources\data\food.csv'
commit_records=read_csv(commit_records_filepath)
print(commit_records.head())
# Write DataFrame to MySQL table
engine = create_engine(mysql_conn_str)
commit_records[["id","caterer_id","name","price","description","image_path","ingredient","nutrition","allergen","type"]].to_sql('food', con=engine, if_exists='append', index=False)
# Close cursor and connection
cursor.close()
# Out:
#    id  caterer_id   name  price description  \
# 0   1           7  sushi   2.78       Dolor
# 1   2          10  salad   9.66       Dolor
# 2   3           4   soup   8.25       Ipsum
# 3   4           8  pizza   9.32       Ipsum
# 4   5           3   soup   1.74       Ipsum
#
#                                         image_path ingredient nutrition  \
# 0  http://dummyimage.com/168x100.png/cc0000/ffffff          a         a
# 1  http://dummyimage.com/175x100.png/dddddd/000000          a         a
# 2  http://dummyimage.com/221x100.png/ff4444/ffffff          a         a
# 3  http://dummyimage.com/212x100.png/ff4444/ffffff          a         a
# 4  http://dummyimage.com/194x100.png/5fa2dd/ffffff          a         a
#
#   allergen           type
# 0        a        Chinese
# 1        a  Mediterranean
# 2        a        Italian
# 3        a       Japanese
# 4        a  Mediterranean
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1938, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1937     if not evt_handled:
# -> 1938         self.dialect.do_executemany(
#    1939             cursor,
#    1940             str_statement,
#    1941             effective_parameters,
#    1942             context,
#    1943         )
#    1944 elif not effective_parameters and context.no_parameters:
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:175, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     174 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 175     rowcount = cursor.executemany(statement, parameters)
#     176     if context is not None:
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:187, in Cursor.executemany(self, query, args)
#     186     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 187     return self._do_execute_many(
#     188         q_prefix,
#     189         q_values,
#     190         q_postfix,
#     191         args,
#     192         self.max_stmt_length,
#     193         self._get_db().encoding,
#     194     )
#     196 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:225, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     224     sql += v
# --> 225 rows += self.execute(sql + postfix)
#     226 self.rowcount = rows
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:158, in Cursor.execute(self, query, args)
#     156 query = self.mogrify(query, args)
# --> 158 result = self._query(query)
#     159 self._executed = query
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:325, in Cursor._query(self, q)
#     324 self._clear_result()
# --> 325 conn.query(q)
#     326 self._do_get_result()
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:549, in Connection.query(self, sql, unbuffered)
#     548 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 549 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550 return self._affected_rows
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:779, in Connection._read_query_result(self, unbuffered)
#     778     result = MySQLResult(self)
# --> 779     result.read()
#     780 self._result = result
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:1157, in MySQLResult.read(self)
#    1156 try:
# -> 1157     first_packet = self.connection._read_packet()
#    1159     if first_packet.is_ok_packet():
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:729, in Connection._read_packet(self, packet_type)
#     728         self._result.unbuffered_active = False
# --> 729     packet.raise_for_error()
#     730 return packet
#
# File d:\program\python\environment\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File d:\program\python\environment\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry '1' for key 'food.PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[6], line 6
#       4 # Write DataFrame to MySQL table
#       5 engine = create_engine(mysql_conn_str)
# ----> 6 commit_records[["id","caterer_id","name","price","description","image_path","ingredient","nutrition","allergen","type"]].to_sql('food', con=engine, if_exists='append', index=False)
#       7 # Close cursor and connection
#       8 cursor.close()
#
# File d:\program\python\environment\Lib\site-packages\pandas\core\generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:769, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
#     768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#     772         if_exists=if_exists,
#     773         index=index,
#     774         index_label=index_label,
#     775         schema=schema,
#     776         chunksize=chunksize,
#     777         dtype=dtype,
#     778         method=method,
#     779         engine=engine,
#     780         **engine_kwargs,
#     781     )
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:1920, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1908 sql_engine = get_engine(engine)
#    1910 table = self.prep_table(
#    1911     frame=frame,
#    1912     name=name,
#    (...)
#    1917     dtype=dtype,
#    1918 )
# -> 1920 total_inserted = sql_engine.insert_records(
#    1921     table=table,
#    1922     con=self.con,
#    1923     frame=frame,
#    1924     name=name,
#    1925     index=index,
#    1926     schema=schema,
#    1927     chunksize=chunksize,
#    1928     method=method,
#    1929     **engine_kwargs,
#    1930 )
#    1932 self.check_case_sensitive(name=name, schema=schema)
#    1933 return total_inserted
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:1470, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1468 if re.search(msg, err_text):
#    1469     raise ValueError("inf cannot be used with MySQL") from err
# -> 1470 raise err
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:1461, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1458 from sqlalchemy import exc
#    1460 try:
# -> 1461     return table.insert(chunksize=chunksize, method=method)
#    1462 except exc.StatementError as err:
#    1463     # GH34431
#    1464     # https://stackoverflow.com/a/67358288/6067848
#    1465     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1466     )|inf can not be used with MySQL"""
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:1023, in SQLTable.insert(self, chunksize, method)
#    1020     break
#    1022 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1023 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1024 # GH 46891
#    1025 if is_integer(num_inserted):
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:929, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     917 """
#     918 Execute SQL statement inserting data
#     919
#    (...)
#     926    Each item contains a list of values to be inserted
#     927 """
#     928 data = [dict(zip(keys, row)) for row in data_iter]
# --> 929 result = conn.execute(self.table.insert(), data)
#     930 return result.rowcount
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\sql\elements.py:517, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     515     if TYPE_CHECKING:
#     516         assert isinstance(self, Executable)
# --> 517     return connection._execute_clauseelement(
#     518         self, distilled_params, execution_options
#     519     )
#     520 else:
#     521     raise exc.ObjectNotExecutableError(self)
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1639, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1627 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1628     "compiled_cache", self.engine._compiled_cache
#    1629 )
#    1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    (...)
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
# -> 1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    1642     compiled_sql,
#    1643     distilled_parameters,
#    1644     execution_options,
#    1645     compiled_sql,
#    1646     distilled_parameters,
#    1647     elem,
#    1648     extracted_params,
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#    1652     self.dispatch.after_execute(
#    1653         self,
#    1654         elem,
#    (...)
#    1658         ret,
#    1659     )
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:2344, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2342 elif should_wrap:
#    2343     assert sqlalchemy_exception is not None
# -> 2344     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2345 else:
#    2346     assert exc_info[1] is not None
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1938, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1936                 break
#    1937     if not evt_handled:
# -> 1938         self.dialect.do_executemany(
#    1939             cursor,
#    1940             str_statement,
#    1941             effective_parameters,
#    1942             context,
#    1943         )
#    1944 elif not effective_parameters and context.no_parameters:
#    1945     if self.dialect._has_events:
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:175, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     174 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 175     rowcount = cursor.executemany(statement, parameters)
#     176     if context is not None:
#     177         context._rowcount = rowcount
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:187, in Cursor.executemany(self, query, args)
#     185     q_postfix = m.group(3) or ""
#     186     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 187     return self._do_execute_many(
#     188         q_prefix,
#     189         q_values,
#     190         q_postfix,
#     191         args,
#     192         self.max_stmt_length,
#     193         self._get_db().encoding,
#     194     )
#     196 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     197 return self.rowcount
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:225, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     223         sql += b","
#     224     sql += v
# --> 225 rows += self.execute(sql + postfix)
#     226 self.rowcount = rows
#     227 return rows
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:158, in Cursor.execute(self, query, args)
#     154     pass
#     156 query = self.mogrify(query, args)
# --> 158 result = self._query(query)
#     159 self._executed = query
#     160 return result
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:325, in Cursor._query(self, q)
#     323 conn = self._get_db()
#     324 self._clear_result()
# --> 325 conn.query(q)
#     326 self._do_get_result()
#     327 return self.rowcount
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:549, in Connection.query(self, sql, unbuffered)
#     547     sql = sql.encode(self.encoding, "surrogateescape")
#     548 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 549 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550 return self._affected_rows
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:779, in Connection._read_query_result(self, unbuffered)
#     777 else:
#     778     result = MySQLResult(self)
# --> 779     result.read()
#     780 self._result = result
#     781 if result.server_status is not None:
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:1157, in MySQLResult.read(self)
#    1155 def read(self):
#    1156     try:
# -> 1157         first_packet = self.connection._read_packet()
#    1159         if first_packet.is_ok_packet():
#    1160             self._read_ok_packet(first_packet)
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:729, in Connection._read_packet(self, packet_type)
#     727     if self._result is not None and self._result.unbuffered_active is True:
#     728         self._result.unbuffered_active = False
# --> 729     packet.raise_for_error()
#     730 return packet
#
# File d:\program\python\environment\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File d:\program\python\environment\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry '1' for key 'food.PRIMARY'")
# [SQL: INSERT INTO food (id, caterer_id, name, price, description, image_path, ingredient, nutrition, allergen, type) VALUES (%(id)s, %(caterer_id)s, %(name)s, %(price)s, %(description)s, %(image_path)s, %(ingredient)s, %(nutrition)s, %(allergen)s, %(type)s)]
# [parameters: [{'id': 1, 'caterer_id': 7, 'name': 'sushi', 'price': 2.78, 'description': 'Dolor', 'image_path': 'http://dummyimage.com/168x100.png/cc0000/ffffff', 'ingredient': 'a', 'nutrition': 'a', 'allergen': 'a', 'type': 'Chinese'}, {'id': 2, 'caterer_id': 10, 'name': 'salad', 'price': 9.66, 'description': 'Dolor', 'image_path': 'http://dummyimage.com/175x100.png/dddddd/000000', 'ingredient': 'a', 'nutrition': 'a', 'allergen': 'a', 'type': 'Mediterranean'}, {'id': 3, 'caterer_id': 4, 'name': 'soup', 'price': 8.25, 'description': 'Ipsum', 'image_path': 'http://dummyimage.com/221x100.png/ff4444/ffffff', 'ingredient': 'a', 'nutrition': 'a', 'allergen': 'a', 'type': 'Italian'}, {'id': 4, 'caterer_id': 8, 'name': 'pizza', 'price': 9.32, 'description': 'Ipsum', 'image_path': 'http://dummyimage.com/212x100.png/ff4444/ffffff', 'ingredient': 'a', 'nutrition': 'a', 'allergen': 'a', 'type': 'Japanese'}, {'id': 5, 'caterer_id': 3, 'name': 'soup', 'price': 1.74, 'description': 'Ipsum', 'image_path': 'http://dummyimage.com/194x100.png/5fa2dd/ffffff', 'ingredient': 'a', 'nutrition': 'a', 'allergen': 'a', 'type': 'Mediterranean'}, {'id': 6, 'caterer_id': 10, 'name': 'taco', 'price': 5.7, 'description': 'Sit', 'image_path': 'http://dummyimage.com/170x100.png/5fa2dd/ffffff', 'ingredient': 'a', 'nutrition': 'a', 'allergen': 'a', 'type': 'Japanese'}, {'id': 7, 'caterer_id': 11, 'name': 'steak', 'price': 1.67, 'description': 'Consectetur', 'image_path': 'http://dummyimage.com/169x100.png/ff4444/ffffff', 'ingredient': 'a', 'nutrition': 'a', 'allergen': 'a', 'type': 'Indian'}, {'id': 8, 'caterer_id': 5, 'name': 'sushi', 'price': 2.66, 'description': 'Amet', 'image_path': 'http://dummyimage.com/183x100.png/5fa2dd/ffffff', 'ingredient': 'a', 'nutrition': 'a', 'allergen': 'a', 'type': 'Japanese'}  ... displaying 10 of 50 total bound parameter sets ...  {'id': 49, 'caterer_id': 4, 'name': 'taco', 'price': 3.64, 'description': 'Sit', 'image_path': 'http://dummyimage.com/187x100.png/ff4444/ffffff', 'ingredient': 'a', 'nutrition': 'a', 'allergen': 'a', 'type': 'Italian'}, {'id': 50, 'caterer_id': 19, 'name': 'salad', 'price': 7.21, 'description': 'Adipiscing', 'image_path': 'http://dummyimage.com/145x100.png/dddddd/000000', 'ingredient': 'a', 'nutrition': 'a', 'allergen': 'a', 'type': 'Indian'}]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
commit_records_filepath = r'src\main\resources\data\food_collect.csv'
commit_records=read_csv(commit_records_filepath)
print(commit_records.head())
# Write DataFrame to MySQL table
engine = create_engine(mysql_conn_str)
commit_records[['user_id','food_id']].to_sql('food_collect', con=engine, if_exists='append', index=False)
# Close cursor and connection
cursor.close()
# Out:
#    user_id  food_id
# 0       24       37
# 1        6       24
# 2       44       12
# 3       13       20
# 4       23       49
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1938, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1937     if not evt_handled:
# -> 1938         self.dialect.do_executemany(
#    1939             cursor,
#    1940             str_statement,
#    1941             effective_parameters,
#    1942             context,
#    1943         )
#    1944 elif not effective_parameters and context.no_parameters:
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:175, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     174 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 175     rowcount = cursor.executemany(statement, parameters)
#     176     if context is not None:
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:187, in Cursor.executemany(self, query, args)
#     186     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 187     return self._do_execute_many(
#     188         q_prefix,
#     189         q_values,
#     190         q_postfix,
#     191         args,
#     192         self.max_stmt_length,
#     193         self._get_db().encoding,
#     194     )
#     196 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:225, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     224     sql += v
# --> 225 rows += self.execute(sql + postfix)
#     226 self.rowcount = rows
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:158, in Cursor.execute(self, query, args)
#     156 query = self.mogrify(query, args)
# --> 158 result = self._query(query)
#     159 self._executed = query
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:325, in Cursor._query(self, q)
#     324 self._clear_result()
# --> 325 conn.query(q)
#     326 self._do_get_result()
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:549, in Connection.query(self, sql, unbuffered)
#     548 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 549 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550 return self._affected_rows
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:779, in Connection._read_query_result(self, unbuffered)
#     778     result = MySQLResult(self)
# --> 779     result.read()
#     780 self._result = result
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:1157, in MySQLResult.read(self)
#    1156 try:
# -> 1157     first_packet = self.connection._read_packet()
#    1159     if first_packet.is_ok_packet():
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:729, in Connection._read_packet(self, packet_type)
#     728         self._result.unbuffered_active = False
# --> 729     packet.raise_for_error()
#     730 return packet
#
# File d:\program\python\environment\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File d:\program\python\environment\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry '24-37' for key 'food_collect.PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[9], line 6
#       4 # Write DataFrame to MySQL table
#       5 engine = create_engine(mysql_conn_str)
# ----> 6 commit_records[['user_id','food_id']].to_sql('food_collect', con=engine, if_exists='append', index=False)
#       7 # Close cursor and connection
#       8 cursor.close()
#
# File d:\program\python\environment\Lib\site-packages\pandas\core\generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:769, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
#     768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#     772         if_exists=if_exists,
#     773         index=index,
#     774         index_label=index_label,
#     775         schema=schema,
#     776         chunksize=chunksize,
#     777         dtype=dtype,
#     778         method=method,
#     779         engine=engine,
#     780         **engine_kwargs,
#     781     )
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:1920, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1908 sql_engine = get_engine(engine)
#    1910 table = self.prep_table(
#    1911     frame=frame,
#    1912     name=name,
#    (...)
#    1917     dtype=dtype,
#    1918 )
# -> 1920 total_inserted = sql_engine.insert_records(
#    1921     table=table,
#    1922     con=self.con,
#    1923     frame=frame,
#    1924     name=name,
#    1925     index=index,
#    1926     schema=schema,
#    1927     chunksize=chunksize,
#    1928     method=method,
#    1929     **engine_kwargs,
#    1930 )
#    1932 self.check_case_sensitive(name=name, schema=schema)
#    1933 return total_inserted
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:1470, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1468 if re.search(msg, err_text):
#    1469     raise ValueError("inf cannot be used with MySQL") from err
# -> 1470 raise err
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:1461, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1458 from sqlalchemy import exc
#    1460 try:
# -> 1461     return table.insert(chunksize=chunksize, method=method)
#    1462 except exc.StatementError as err:
#    1463     # GH34431
#    1464     # https://stackoverflow.com/a/67358288/6067848
#    1465     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1466     )|inf can not be used with MySQL"""
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:1023, in SQLTable.insert(self, chunksize, method)
#    1020     break
#    1022 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1023 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1024 # GH 46891
#    1025 if is_integer(num_inserted):
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:929, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     917 """
#     918 Execute SQL statement inserting data
#     919
#    (...)
#     926    Each item contains a list of values to be inserted
#     927 """
#     928 data = [dict(zip(keys, row)) for row in data_iter]
# --> 929 result = conn.execute(self.table.insert(), data)
#     930 return result.rowcount
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\sql\elements.py:517, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     515     if TYPE_CHECKING:
#     516         assert isinstance(self, Executable)
# --> 517     return connection._execute_clauseelement(
#     518         self, distilled_params, execution_options
#     519     )
#     520 else:
#     521     raise exc.ObjectNotExecutableError(self)
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1639, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1627 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1628     "compiled_cache", self.engine._compiled_cache
#    1629 )
#    1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    (...)
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
# -> 1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    1642     compiled_sql,
#    1643     distilled_parameters,
#    1644     execution_options,
#    1645     compiled_sql,
#    1646     distilled_parameters,
#    1647     elem,
#    1648     extracted_params,
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#    1652     self.dispatch.after_execute(
#    1653         self,
#    1654         elem,
#    (...)
#    1658         ret,
#    1659     )
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:2344, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2342 elif should_wrap:
#    2343     assert sqlalchemy_exception is not None
# -> 2344     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2345 else:
#    2346     assert exc_info[1] is not None
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1938, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1936                 break
#    1937     if not evt_handled:
# -> 1938         self.dialect.do_executemany(
#    1939             cursor,
#    1940             str_statement,
#    1941             effective_parameters,
#    1942             context,
#    1943         )
#    1944 elif not effective_parameters and context.no_parameters:
#    1945     if self.dialect._has_events:
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:175, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     174 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 175     rowcount = cursor.executemany(statement, parameters)
#     176     if context is not None:
#     177         context._rowcount = rowcount
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:187, in Cursor.executemany(self, query, args)
#     185     q_postfix = m.group(3) or ""
#     186     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 187     return self._do_execute_many(
#     188         q_prefix,
#     189         q_values,
#     190         q_postfix,
#     191         args,
#     192         self.max_stmt_length,
#     193         self._get_db().encoding,
#     194     )
#     196 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     197 return self.rowcount
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:225, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     223         sql += b","
#     224     sql += v
# --> 225 rows += self.execute(sql + postfix)
#     226 self.rowcount = rows
#     227 return rows
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:158, in Cursor.execute(self, query, args)
#     154     pass
#     156 query = self.mogrify(query, args)
# --> 158 result = self._query(query)
#     159 self._executed = query
#     160 return result
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:325, in Cursor._query(self, q)
#     323 conn = self._get_db()
#     324 self._clear_result()
# --> 325 conn.query(q)
#     326 self._do_get_result()
#     327 return self.rowcount
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:549, in Connection.query(self, sql, unbuffered)
#     547     sql = sql.encode(self.encoding, "surrogateescape")
#     548 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 549 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550 return self._affected_rows
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:779, in Connection._read_query_result(self, unbuffered)
#     777 else:
#     778     result = MySQLResult(self)
# --> 779     result.read()
#     780 self._result = result
#     781 if result.server_status is not None:
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:1157, in MySQLResult.read(self)
#    1155 def read(self):
#    1156     try:
# -> 1157         first_packet = self.connection._read_packet()
#    1159         if first_packet.is_ok_packet():
#    1160             self._read_ok_packet(first_packet)
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:729, in Connection._read_packet(self, packet_type)
#     727     if self._result is not None and self._result.unbuffered_active is True:
#     728         self._result.unbuffered_active = False
# --> 729     packet.raise_for_error()
#     730 return packet
#
# File d:\program\python\environment\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File d:\program\python\environment\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry '24-37' for key 'food_collect.PRIMARY'")
# [SQL: INSERT INTO food_collect (user_id, food_id) VALUES (%(user_id)s, %(food_id)s)]
# [parameters: [{'user_id': 24, 'food_id': 37}, {'user_id': 6, 'food_id': 24}, {'user_id': 44, 'food_id': 12}, {'user_id': 13, 'food_id': 20}, {'user_id': 23, 'food_id': 49}, {'user_id': 40, 'food_id': 18}, {'user_id': 47, 'food_id': 13}, {'user_id': 36, 'food_id': 31}  ... displaying 10 of 100 total bound parameter sets ...  {'user_id': 31, 'food_id': 43}, {'user_id': 40, 'food_id': 25}]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
commit_records_filepath = r'src\main\resources\data\caterer_collect.csv'
commit_records=read_csv(commit_records_filepath)
print(commit_records.head())
# Write DataFrame to MySQL table
engine = create_engine(mysql_conn_str)
commit_records[['user_id','caterer_id']].to_sql('caterer_collect', con=engine, if_exists='append', index=False)
# Close cursor and connection
cursor.close()
# Out:
#    user_id  caterer_id
# 0       29           6
# 1        6           2
# 2       30          20
# 3        9          19
# 4       50           2
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1938, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1937     if not evt_handled:
# -> 1938         self.dialect.do_executemany(
#    1939             cursor,
#    1940             str_statement,
#    1941             effective_parameters,
#    1942             context,
#    1943         )
#    1944 elif not effective_parameters and context.no_parameters:
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:175, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     174 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 175     rowcount = cursor.executemany(statement, parameters)
#     176     if context is not None:
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:187, in Cursor.executemany(self, query, args)
#     186     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 187     return self._do_execute_many(
#     188         q_prefix,
#     189         q_values,
#     190         q_postfix,
#     191         args,
#     192         self.max_stmt_length,
#     193         self._get_db().encoding,
#     194     )
#     196 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:225, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     224     sql += v
# --> 225 rows += self.execute(sql + postfix)
#     226 self.rowcount = rows
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:158, in Cursor.execute(self, query, args)
#     156 query = self.mogrify(query, args)
# --> 158 result = self._query(query)
#     159 self._executed = query
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:325, in Cursor._query(self, q)
#     324 self._clear_result()
# --> 325 conn.query(q)
#     326 self._do_get_result()
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:549, in Connection.query(self, sql, unbuffered)
#     548 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 549 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550 return self._affected_rows
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:779, in Connection._read_query_result(self, unbuffered)
#     778     result = MySQLResult(self)
# --> 779     result.read()
#     780 self._result = result
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:1157, in MySQLResult.read(self)
#    1156 try:
# -> 1157     first_packet = self.connection._read_packet()
#    1159     if first_packet.is_ok_packet():
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:729, in Connection._read_packet(self, packet_type)
#     728         self._result.unbuffered_active = False
# --> 729     packet.raise_for_error()
#     730 return packet
#
# File d:\program\python\environment\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File d:\program\python\environment\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry '29-6' for key 'caterer_collect.PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[10], line 6
#       4 # Write DataFrame to MySQL table
#       5 engine = create_engine(mysql_conn_str)
# ----> 6 commit_records[['user_id','caterer_id']].to_sql('caterer_collect', con=engine, if_exists='append', index=False)
#       7 # Close cursor and connection
#       8 cursor.close()
#
# File d:\program\python\environment\Lib\site-packages\pandas\core\generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:769, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
#     768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#     772         if_exists=if_exists,
#     773         index=index,
#     774         index_label=index_label,
#     775         schema=schema,
#     776         chunksize=chunksize,
#     777         dtype=dtype,
#     778         method=method,
#     779         engine=engine,
#     780         **engine_kwargs,
#     781     )
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:1920, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1908 sql_engine = get_engine(engine)
#    1910 table = self.prep_table(
#    1911     frame=frame,
#    1912     name=name,
#    (...)
#    1917     dtype=dtype,
#    1918 )
# -> 1920 total_inserted = sql_engine.insert_records(
#    1921     table=table,
#    1922     con=self.con,
#    1923     frame=frame,
#    1924     name=name,
#    1925     index=index,
#    1926     schema=schema,
#    1927     chunksize=chunksize,
#    1928     method=method,
#    1929     **engine_kwargs,
#    1930 )
#    1932 self.check_case_sensitive(name=name, schema=schema)
#    1933 return total_inserted
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:1470, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1468 if re.search(msg, err_text):
#    1469     raise ValueError("inf cannot be used with MySQL") from err
# -> 1470 raise err
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:1461, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1458 from sqlalchemy import exc
#    1460 try:
# -> 1461     return table.insert(chunksize=chunksize, method=method)
#    1462 except exc.StatementError as err:
#    1463     # GH34431
#    1464     # https://stackoverflow.com/a/67358288/6067848
#    1465     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1466     )|inf can not be used with MySQL"""
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:1023, in SQLTable.insert(self, chunksize, method)
#    1020     break
#    1022 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1023 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1024 # GH 46891
#    1025 if is_integer(num_inserted):
#
# File d:\program\python\environment\Lib\site-packages\pandas\io\sql.py:929, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     917 """
#     918 Execute SQL statement inserting data
#     919
#    (...)
#     926    Each item contains a list of values to be inserted
#     927 """
#     928 data = [dict(zip(keys, row)) for row in data_iter]
# --> 929 result = conn.execute(self.table.insert(), data)
#     930 return result.rowcount
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\sql\elements.py:517, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     515     if TYPE_CHECKING:
#     516         assert isinstance(self, Executable)
# --> 517     return connection._execute_clauseelement(
#     518         self, distilled_params, execution_options
#     519     )
#     520 else:
#     521     raise exc.ObjectNotExecutableError(self)
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1639, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1627 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1628     "compiled_cache", self.engine._compiled_cache
#    1629 )
#    1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    (...)
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
# -> 1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    1642     compiled_sql,
#    1643     distilled_parameters,
#    1644     execution_options,
#    1645     compiled_sql,
#    1646     distilled_parameters,
#    1647     elem,
#    1648     extracted_params,
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#    1652     self.dispatch.after_execute(
#    1653         self,
#    1654         elem,
#    (...)
#    1658         ret,
#    1659     )
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:2344, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2342 elif should_wrap:
#    2343     assert sqlalchemy_exception is not None
# -> 2344     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2345 else:
#    2346     assert exc_info[1] is not None
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\engine\base.py:1938, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1936                 break
#    1937     if not evt_handled:
# -> 1938         self.dialect.do_executemany(
#    1939             cursor,
#    1940             str_statement,
#    1941             effective_parameters,
#    1942             context,
#    1943         )
#    1944 elif not effective_parameters and context.no_parameters:
#    1945     if self.dialect._has_events:
#
# File d:\program\python\environment\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:175, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     174 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 175     rowcount = cursor.executemany(statement, parameters)
#     176     if context is not None:
#     177         context._rowcount = rowcount
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:187, in Cursor.executemany(self, query, args)
#     185     q_postfix = m.group(3) or ""
#     186     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 187     return self._do_execute_many(
#     188         q_prefix,
#     189         q_values,
#     190         q_postfix,
#     191         args,
#     192         self.max_stmt_length,
#     193         self._get_db().encoding,
#     194     )
#     196 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     197 return self.rowcount
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:225, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     223         sql += b","
#     224     sql += v
# --> 225 rows += self.execute(sql + postfix)
#     226 self.rowcount = rows
#     227 return rows
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:158, in Cursor.execute(self, query, args)
#     154     pass
#     156 query = self.mogrify(query, args)
# --> 158 result = self._query(query)
#     159 self._executed = query
#     160 return result
#
# File d:\program\python\environment\Lib\site-packages\pymysql\cursors.py:325, in Cursor._query(self, q)
#     323 conn = self._get_db()
#     324 self._clear_result()
# --> 325 conn.query(q)
#     326 self._do_get_result()
#     327 return self.rowcount
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:549, in Connection.query(self, sql, unbuffered)
#     547     sql = sql.encode(self.encoding, "surrogateescape")
#     548 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 549 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550 return self._affected_rows
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:779, in Connection._read_query_result(self, unbuffered)
#     777 else:
#     778     result = MySQLResult(self)
# --> 779     result.read()
#     780 self._result = result
#     781 if result.server_status is not None:
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:1157, in MySQLResult.read(self)
#    1155 def read(self):
#    1156     try:
# -> 1157         first_packet = self.connection._read_packet()
#    1159         if first_packet.is_ok_packet():
#    1160             self._read_ok_packet(first_packet)
#
# File d:\program\python\environment\Lib\site-packages\pymysql\connections.py:729, in Connection._read_packet(self, packet_type)
#     727     if self._result is not None and self._result.unbuffered_active is True:
#     728         self._result.unbuffered_active = False
# --> 729     packet.raise_for_error()
#     730 return packet
#
# File d:\program\python\environment\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File d:\program\python\environment\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry '29-6' for key 'caterer_collect.PRIMARY'")
# [SQL: INSERT INTO caterer_collect (user_id, caterer_id) VALUES (%(user_id)s, %(caterer_id)s)]
# [parameters: [{'user_id': 29, 'caterer_id': 6}, {'user_id': 6, 'caterer_id': 2}, {'user_id': 30, 'caterer_id': 20}, {'user_id': 9, 'caterer_id': 19}, {'user_id': 50, 'caterer_id': 2}, {'user_id': 20, 'caterer_id': 9}, {'user_id': 22, 'caterer_id': 3}, {'user_id': 47, 'caterer_id': 20}  ... displaying 10 of 30 total bound parameter sets ...  {'user_id': 29, 'caterer_id': 14}, {'user_id': 25, 'caterer_id': 18}]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
commit_records_filepath = r'src\main\resources\data\food_comment.csv'
commit_records=read_csv(commit_records_filepath)
print(commit_records.head())
# Write DataFrame to MySQL table
engine = create_engine(mysql_conn_str)
commit_records[["food_id","user_id","comment","grade"]].to_sql('food_comment', con=engine, if_exists='append', index=False)
# Close cursor and connection
cursor.close()
# Out:
#    food_id  user_id      comment  grade
# 0       25       42   Great job!      2
# 1       44       20  Impressive!      3
# 2       29        9   Great job!      2
# 3       12       20   Nice work!      5
# 4       39        6   Nice work!      3

# %%
commit_records_filepath = r'src\main\resources\data\caterer_comment.csv'
commit_records=read_csv(commit_records_filepath)
print(commit_records.head())
# Write DataFrame to MySQL table
engine = create_engine(mysql_conn_str)
commit_records[["caterer_id","user_id","comment","grade"]].to_sql('caterer_comment', con=engine, if_exists='append', index=False)
# Close cursor and connection
cursor.close()
# Out:
#    caterer_id  user_id      comment  grade
# 0          19       41   Nice work!      2
# 1           8       44  Impressive!      2
# 2          11        8   Well done!      4
# 3          16       44   Well done!      4
# 4          10       12   Great job!      0

# %%
commit_records_filepath = r'src\main\resources\data\orders.csv'
commit_records=read_csv(commit_records_filepath)
print(commit_records.head())
# Write DataFrame to MySQL table
engine = create_engine(mysql_conn_str)
commit_records[["id","time","user_id","caterer_id","is_queue_order","is_finished"]].to_sql('orders', con=engine, if_exists='append', index=False)
# Close cursor and connection
cursor.close()
# Out:
#    id                 time  user_id  caterer_id  is_queue_order  is_finished
# 0   1  2023-09-18 19:19:37       14          19               0            1
# 1   2  2024-01-20 06:27:38        7          19               0            1
# 2   3  2024-01-16 23:12:20        8          14               0            1
# 3   4  2023-10-25 23:57:19       21          15               0            1
# 4   5  2023-09-06 22:57:09       42           1               0            1

# %%
commit_records_filepath = r'src\main\resources\data\order_food.csv'
commit_records=read_csv(commit_records_filepath)
print(commit_records.head())
# Write DataFrame to MySQL table
engine = create_engine(mysql_conn_str)
commit_records[['order_id','food_id']].to_sql('order_food', con=engine, if_exists='append', index=False)
# Close cursor and connection
cursor.close()
# Out:
#    order_id  food_id  quantity
# 0         1       24         4
# 1         1       50         3
# 2         1       45         4
# 3         2       24         8
# 4         3       38         9
